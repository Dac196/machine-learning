# %%
import pandas as pd
Null_values =["?"] # se identifican valores nulos dentro del data set
nRowsRead=None
COLUMNS2 = ['ClassName', 'handicapped-infants', 'water-project-cost-sharing',
           'adoption-of-the-budget-resolution', 'education_num','marital',
           'physician-fee-freeze', 'el-salvador-aid', 'religious-groups-in-schools',
           'anti-satellite-test-ban', 'aid-to-nicaraguan-contras', 'mx-missile',
           'immigration', 'synfuels-corporation-cutback', 'education-spending',
           'superfund-right-to-sue', 'crime','duty-free-exports', 'export-administration-act-south-africa']
PATH ='house-votes-84.data'
df_house = pd.read_csv(PATH, delimiter=',', nrows = nRowsRead, names = COLUMNS2, na_values = Null_values)
df_house.dataframeName ='house-votes-84.csv'
nRow,nCol = df_house.shape
print(df_house)
# Out:
#       ClassName handicapped-infants water-project-cost-sharing  \
# 0    republican                   n                          y
# 1    republican                   n                          y
# 2      democrat                 NaN                          y
# 3      democrat                   n                          y
# 4      democrat                   y                          y
# ..          ...                 ...                        ...
# 430  republican                   n                          n
# 431    democrat                   n                          n
# 432  republican                   n                        NaN
# 433  republican                   n                          n
# 434  republican                   n                          y
#
#     adoption-of-the-budget-resolution education_num marital  \
# 0                                   n             y       y
# 1                                   n             y       y
# ...

# %% [markdown]
# Se eliminan los titulos 'duty-free-exports',      'export-administration-act-south-africa mencionados en la guia dado que en el data set son nulos y no aportan información al modelo

# %%
df_house.drop (["duty-free-exports","export-administration-act-south-africa"],axis=1,inplace = True)

# %%
df_house.head()
# Out:
#     ClassName handicapped-infants water-project-cost-sharing  \
# 0  republican                   n                          y
# 1  republican                   n                          y
# 2    democrat                 NaN                          y
# 3    democrat                   n                          y
# 4    democrat                   y                          y
#
#   adoption-of-the-budget-resolution education_num marital  \
# 0                                 n             y       y
# 1                                 n             y       y
# 2                                 y           NaN       y
# 3                                 y             n     NaN
# 4                                 y             n       y
#
#   physician-fee-freeze el-salvador-aid religious-groups-in-schools  \
# 0                    y               n                           n
# 1                    y               n                           n
# ...

# %%
df_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ClassName                          435 non-null    object
#  1   handicapped-infants                423 non-null    object
#  2   water-project-cost-sharing         387 non-null    object
#  3   adoption-of-the-budget-resolution  424 non-null    object
#  4   education_num                      424 non-null    object
#  5   marital                            420 non-null    object
#  6   physician-fee-freeze               424 non-null    object
#  7   el-salvador-aid                    421 non-null    object
#  8   religious-groups-in-schools        420 non-null    object
#  9   anti-satellite-test-ban            413 non-null    object
#  10  aid-to-nicaraguan-contras          428 non-null    object
# ...

# %% [markdown]
# Se identifican que todas las variables son categoricas

# %%
df_house.isnull().sum()
# Out:
# ClassName                              0
# handicapped-infants                   12
# water-project-cost-sharing            48
# adoption-of-the-budget-resolution     11
# education_num                         11
# marital                               15
# physician-fee-freeze                  11
# el-salvador-aid                       14
# religious-groups-in-schools           15
# anti-satellite-test-ban               22
# aid-to-nicaraguan-contras              7
# mx-missile                            21
# immigration                           31
# synfuels-corporation-cutback          25
# education-spending                    17
# superfund-right-to-sue                28
# crime                                104
# dtype: int64

# %% [markdown]
# Se suma para conocer cuantos datos nulos o faltantes se tienen

# %%
df_house = df_house.fillna(method="bfill")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6b4c03fc1007> in <module>
# ----> 1 df_house.fillna(method="bfill")
#
# NameError: name 'df_house' is not defined

# %% [markdown]
# Se utiliza el metodo bfill para reemplazar los valores nulos se rellenen con el siguiente valor no nulo

# %%
df_house.describe()
# Out:
#        ClassName handicapped-infants water-project-cost-sharing  \
# count        435                 423                        387
# unique         2                   2                          2
# top     democrat                   n                          y
# freq         267                 236                        195
#
#        adoption-of-the-budget-resolution education_num marital  \
# count                                424           424     420
# unique                                 2             2       2
# top                                    y             n       y
# freq                                 253           247     212
#
#        physician-fee-freeze el-salvador-aid religious-groups-in-schools  \
# count                   424             421                         420
# unique                    2               2                           2
# top                       y               y                           y
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="ClassName", data=df_house)
plt.show()
